# %% [markdown]
# # Cisco DNA Center API

# %% [markdown]
# ## How to get a token
# All Cisco DNA Center API calls are authenticated.  Here is a code snippet to get a valid token.
#
# The "dnac_config.py" file contains variables for the controller and the username and password

# %%
from dnac_config import DNAC, DNAC_PORT, DNAC_USER, DNAC_PASSWORD
import requests
from requests.auth import HTTPBasicAuth
requests.packages.urllib3.disable_warnings()

# %%
login_url = "https://{0}:{1}/api/system/v1/auth/token".format(DNAC, DNAC_PORT)
result = requests.post(url=login_url, auth=HTTPBasicAuth(DNAC_USER, DNAC_PASSWORD), verify=False)
result.raise_for_status()
token = result.json()["Token"]

# %%
print (token)
# Out:
# eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9..khN7qOFPwDpAa6Ny9tcBnpPoZ4NsIQFZ5Blb83Z6hSM

# %% [markdown]
# ## Using some predefined functions

# %%
from __future__ import print_function
import sys
import json
from util import get_url, deploy_and_wait, post_and_wait

# %%
response = get_url("dna/intent/api/v1/network-device")
# Out:
# https://sandboxdnac2.cisco.com:8080/dna/intent/api/v1/network-device

# %%
print(json.dumps(response,indent=2))
# Out:
# {
#   "version": "1.0",
#   "response": [
#     {
#       "macAddress": "50:61:bf:57:2f:00",
#       "upTime": "43 days, 4:49:00.00",
#       "bootDateTime": "2019-01-19 02:33:05",
#       "lastUpdateTime": 1551751553587,
#       "snmpContact": "",
#       "lineCardCount": null,
#       "series": "Cisco 3500 Series Wireless LAN Controller",
#       "errorCode": null,
#       "softwareType": "Cisco Controller",
#       "interfaceCount": "8",
#       "tunnelUdpPort": "16666",
#       "id": "50c96308-84b5-43dc-ad68-cda146d80290",
#       "locationName": null,
#       "associatedWlcIp": "",
#       "instanceUuid": "50c96308-84b5-43dc-ad68-cda146d80290",
#       "family": "Wireless Controller",
#       "reachabilityFailureReason": "",
#       "reachabilityStatus": "Reachable",
#       "hostname": "3504_WLC",
#       "memorySize": "3735302144",
#       "roleSource": "AUTO",
#       "collectionInterval": "Global Default",
#       "platformId": "AIR-CT3504-K9",
#       "collectionStatus": "Managed",
#       "role": "ACCESS",
#       "lineCardId": null,
#       "type": "Cisco 3504 Wireless LAN Controller",
#       "location": null,
#       "waasDeviceMode": null,
#       "apManagerInterfaceIp": "",
#       "errorDescription": null,
#       "lastUpdated": "2019-03-05 02:05:53",
#       "managementIpAddress": "10.10.20.51",
#       "serialNumber": "FCW2218M0B1",
#       "inventoryStatusDetail": "<status><general code=\"SUCCESS\"/></status>",
#       "softwareVersion": "8.5.140.0",
#       "snmpLocation": "",
#       "instanceTenantId": "SYS0",
#       "tagCount": "0"
#     },
#     {
#       "macAddress": "00:72:78:54:d1:00",
#       "upTime": "46 days, 10:51:47.93",
#       "bootDateTime": "2019-01-16 21:49:15",
#       "lastUpdateTime": 1551752522836,
#       "snmpContact": "",
#       "lineCardCount": "1",
#       "series": "Cisco Catalyst 9300 Series Switches",
#       "errorCode": null,
#       "softwareType": "IOS-XE",
#       "interfaceCount": "66",
#       "tunnelUdpPort": null,
#       "id": "6a49c827-9b28-490b-8df0-8b6c3b582d8a",
#       "locationName": null,
#       "associatedWlcIp": "",
#       "instanceUuid": "6a49c827-9b28-490b-8df0-8b6c3b582d8a",
#       "family": "Switches and Hubs",
#       "reachabilityFailureReason": "",
#       "reachabilityStatus": "Reachable",
#       "hostname": "leaf1.labb.local",
#       "memorySize": "888965512",
#       "roleSource": "AUTO",
#       "collectionInterval": "Global Default",
#       "platformId": "C9300-48U",
#       "collectionStatus": "Managed",
#       "role": "ACCESS",
#       "lineCardId": "53ac6145-45ee-4122-84fb-9c729f388868",
#       "type": "Cisco Catalyst 9300 Switch",
#       "location": null,
#       "waasDeviceMode": null,
#       "apManagerInterfaceIp": "",
#       "errorDescription": null,
#       "lastUpdated": "2019-03-05 02:22:02",
#       "managementIpAddress": "10.10.20.81",
#       "serialNumber": "FCW2214L0VK",
#       "inventoryStatusDetail": "<status><general code=\"SUCCESS\"/></status>",
#       "softwareVersion": "16.6.3",
#       "snmpLocation": "",
#       "instanceTenantId": "SYS0",
#       "tagCount": "0"
#     },
#     {
#       "macAddress": "50:61:bf:ec:07:80",
#       "upTime": "46 days, 11:23:25.73",
#       "bootDateTime": "2019-01-16 21:43:15",
#       "lastUpdateTime": 1551752295935,
#       "snmpContact": "",
#       "lineCardCount": "1",
#       "series": "Cisco Catalyst 9300 Series Switches",
#       "errorCode": null,
#       "softwareType": "IOS-XE",
#       "interfaceCount": "66",
#       "tunnelUdpPort": null,
#       "id": "ab470365-58e7-4093-bcc3-46228212983f",
#       "locationName": null,
#       "associatedWlcIp": "",
#       "instanceUuid": "ab470365-58e7-4093-bcc3-46228212983f",
#       "family": "Switches and Hubs",
#       "reachabilityFailureReason": "",
#       "reachabilityStatus": "Reachable",
#       "hostname": "leaf2.labb.local",
#       "memorySize": "888965512",
#       "roleSource": "AUTO",
#       "collectionInterval": "Global Default",
#       "platformId": "C9300-48U",
#       "collectionStatus": "Managed",
#       "role": "ACCESS",
#       "lineCardId": "c1e3f935-18da-4953-9da6-a3b0523f54ea",
#       "type": "Cisco Catalyst 9300 Switch",
#       "location": null,
#       "waasDeviceMode": null,
#       "apManagerInterfaceIp": "",
#       "errorDescription": null,
#       "lastUpdated": "2019-03-05 02:18:15",
#       "managementIpAddress": "10.10.20.82",
#       "serialNumber": "FCW2214L0UZ",
#       "inventoryStatusDetail": "<status><general code=\"SUCCESS\"/></status>",
#       "softwareVersion": "16.6.3",
#       "snmpLocation": "",
#       "instanceTenantId": "SYS0",
#       "tagCount": "0"
#     },
#     {
#       "macAddress": "70:01:b5:5d:1b:00",
#       "upTime": "47 days, 11:01:39.93",
#       "bootDateTime": "2019-01-16 15:21:16",
#       "lastUpdateTime": 1551752524510,
#       "snmpContact": "",
#       "lineCardCount": "1",
#       "series": "Cisco Catalyst 3850 Series Ethernet Stackable Switch",
#       "errorCode": null,
#       "softwareType": "IOS-XE",
#       "interfaceCount": "37",
#       "tunnelUdpPort": null,
#       "id": "a119877a-7559-4c2e-935c-3b099188193e",
#       "locationName": null,
#       "associatedWlcIp": "",
#       "instanceUuid": "a119877a-7559-4c2e-935c-3b099188193e",
#       "family": "Switches and Hubs",
#       "reachabilityFailureReason": "",
#       "reachabilityStatus": "Reachable",
#       "hostname": "spine1.abc.in",
#       "memorySize": "885691400",
#       "roleSource": "AUTO",
#       "collectionInterval": "Global Default",
#       "platformId": "WS-C3850-24P-L",
#       "collectionStatus": "Managed",
#       "role": "DISTRIBUTION",
#       "lineCardId": "7384c0e6-159e-40eb-9c13-2f1fbe7d7430",
#       "type": "Cisco Catalyst38xx stack-able ethernet switch",
#       "location": null,
#       "waasDeviceMode": null,
#       "apManagerInterfaceIp": "",
#       "errorDescription": null,
#       "lastUpdated": "2019-03-05 02:22:04",
#       "managementIpAddress": "10.10.20.80",
#       "serialNumber": "FCW2212D05S",
#       "inventoryStatusDetail": "<status><general code=\"SUCCESS\"/></status>",
#       "softwareVersion": "16.3.5b",
#       "snmpLocation": "",
#       "instanceTenantId": "SYS0",
#       "tagCount": "0"
#     },
#     {
#       "macAddress": "00:2b:01:00:02:00",
#       "upTime": "43days 01:17:06.610",
#       "bootDateTime": null,
#       "lastUpdateTime": 1551751553587,
#       "snmpContact": "",
#       "lineCardCount": null,
#       "series": "Cisco 1140 Series Unified Access Points",
#       "errorCode": "null",
#       "softwareType": null,
#       "interfaceCount": null,
#       "tunnelUdpPort": "16666",
#       "id": "8cd186fc-f86e-4123-86ed-fe2b2a41e3fc",
#       "locationName": null,
#       "associatedWlcIp": "10.10.20.51",
#       "instanceUuid": "8cd186fc-f86e-4123-86ed-fe2b2a41e3fc",
#       "family": "Unified AP",
#       "reachabilityFailureReason": "NA",
#       "reachabilityStatus": "Reachable",
#       "hostname": "T1-1",
#       "memorySize": "NA",
#       "roleSource": "AUTO",
#       "collectionInterval": "NA",
#       "platformId": "AIR-AP1141N-A-K9",
#       "collectionStatus": "Managed",
#       "role": "ACCESS",
#       "lineCardId": null,
#       "type": "Cisco 1140 Unified Access Point",
#       "location": null,
#       "waasDeviceMode": null,
#       "apManagerInterfaceIp": "10.10.20.51",
#       "errorDescription": null,
#       "lastUpdated": "2019-03-05 02:05:53",
#       "managementIpAddress": "10.10.20.241",
#       "serialNumber": "1140K0001",
#       "inventoryStatusDetail": "NA",
#       "softwareVersion": "8.6.101.0",
#       "snmpLocation": "default-location",
#       "instanceTenantId": "SYS0",
#       "tagCount": "0"
#     },
#     {
#       "macAddress": "00:2b:01:00:0b:00",
#       "upTime": "1days 19:42:28.060",
#       "bootDateTime": null,
#       "lastUpdateTime": 1551751553587,
#       "snmpContact": "",
#       "lineCardCount": null,
#       "series": "Cisco 1140 Series Unified Access Points",
#       "errorCode": "null",
#       "softwareType": null,
#       "interfaceCount": null,
#       "tunnelUdpPort": "16666",
#       "id": "a2168b2d-adef-4589-b3b5-2add5f37daeb",
#       "locationName": null,
#       "associatedWlcIp": "10.10.20.51",
#       "instanceUuid": "a2168b2d-adef-4589-b3b5-2add5f37daeb",
#       "family": "Unified AP",
#       "reachabilityFailureReason": "NA",
#       "reachabilityStatus": "Unreachable",
#       "hostname": "T1-10",
#       "memorySize": "NA",
#       "roleSource": "AUTO",
#       "collectionInterval": "NA",
#       "platformId": "AIR-AP1141N-A-K9",
#       "collectionStatus": "Unassociated",
#       "role": "ACCESS",
#       "lineCardId": null,
#       "type": "Cisco 1140 Unified Access Point",
#       "location": null,
#       "waasDeviceMode": null,
#       "apManagerInterfaceIp": "10.10.20.51",
#       "errorDescription": null,
#       "lastUpdated": "2019-03-05 02:05:53",
#       "managementIpAddress": "10.10.20.250",
#       "serialNumber": "1140K0010",
#       "inventoryStatusDetail": "NA",
#       "softwareVersion": "8.6.101.0",
#       "snmpLocation": "default-location",
#       "instanceTenantId": "SYS0",
#       "tagCount": "0"
#     },
#     {
#       "macAddress": "00:2b:01:00:03:00",
#       "upTime": "43days 01:17:06.610",
#       "bootDateTime": null,
#       "lastUpdateTime": 1551751553587,
#       "snmpContact": "",
#       "lineCardCount": null,
#       "series": "Cisco 1140 Series Unified Access Points",
#       "errorCode": "null",
#       "softwareType": null,
#       "interfaceCount": null,
#       "tunnelUdpPort": "16666",
#       "id": "0367820f-3aa4-434a-902f-9bd39a8bcd21",
#       "locationName": null,
#       "associatedWlcIp": "10.10.20.51",
#       "instanceUuid": "0367820f-3aa4-434a-902f-9bd39a8bcd21",
#       "family": "Unified AP",
#       "reachabilityFailureReason": "NA",
#       "reachabilityStatus": "Reachable",
#       "hostname": "T1-2",
#       "memorySize": "NA",
#       "roleSource": "AUTO",
#       "collectionInterval": "NA",
#       "platformId": "AIR-AP1141N-A-K9",
#       "collectionStatus": "Managed",
#       "role": "ACCESS",
#       "lineCardId": null,
#       "type": "Cisco 1140 Unified Access Point",
#       "location": null,
#       "waasDeviceMode": null,
#       "apManagerInterfaceIp": "10.10.20.51",
#       "errorDescription": null,
#       "lastUpdated": "2019-03-05 02:05:53",
#       "managementIpAddress": "10.10.20.242",
#       "serialNumber": "1140K0002",
#       "inventoryStatusDetail": "NA",
#       "softwareVersion": "8.6.101.0",
#       "snmpLocation": "default-location",
#       "instanceTenantId": "SYS0",
#       "tagCount": "0"
#     },
#     {
#       "macAddress": "00:2b:01:00:04:00",
#       "upTime": "43days 01:17:07.610",
#       "bootDateTime": null,
#       "lastUpdateTime": 1551751553587,
#       "snmpContact": "",
#       "lineCardCount": null,
#       "series": "Cisco 1140 Series Unified Access Points",
#       "errorCode": "null",
#       "softwareType": null,
#       "interfaceCount": null,
#       "tunnelUdpPort": "16666",
#       "id": "8336ae01-e1a8-47ea-b0bf-68c83618de9e",
#       "locationName": null,
#       "associatedWlcIp": "10.10.20.51",
#       "instanceUuid": "8336ae01-e1a8-47ea-b0bf-68c83618de9e",
#       "family": "Unified AP",
#       "reachabilityFailureReason": "NA",
#       "reachabilityStatus": "Reachable",
#       "hostname": "T1-3",
#       "memorySize": "NA",
#       "roleSource": "AUTO",
#       "collectionInterval": "NA",
#       "platformId": "AIR-AP1141N-A-K9",
#       "collectionStatus": "Managed",
#       "role": "ACCESS",
#       "lineCardId": null,
#       "type": "Cisco 1140 Unified Access Point",
#       "location": null,
#       "waasDeviceMode": null,
#       "apManagerInterfaceIp": "10.10.20.51",
#       "errorDescription": null,
#       "lastUpdated": "2019-03-05 02:05:53",
#       "managementIpAddress": "10.10.20.243",
#       "serialNumber": "1140K0003",
#       "inventoryStatusDetail": "NA",
#       "softwareVersion": "8.6.101.0",
#       "snmpLocation": "default-location",
#       "instanceTenantId": "SYS0",
#       "tagCount": "0"
#     },
#     {
#       "macAddress": "00:2b:01:00:05:00",
#       "upTime": "43days 01:17:07.610",
#       "bootDateTime": null,
#       "lastUpdateTime": 1551751553587,
#       "snmpContact": "",
#       "lineCardCount": null,
#       "series": "Cisco 1140 Series Unified Access Points",
#       "errorCode": "null",
#       "softwareType": null,
#       "interfaceCount": null,
#       "tunnelUdpPort": "16666",
#       "id": "b65cea84-b0c2-4c44-a2e8-1668460bd876",
#       "locationName": null,
#       "associatedWlcIp": "10.10.20.51",
#       "instanceUuid": "b65cea84-b0c2-4c44-a2e8-1668460bd876",
#       "family": "Unified AP",
#       "reachabilityFailureReason": "NA",
#       "reachabilityStatus": "Reachable",
#       "hostname": "T1-4",
#       "memorySize": "NA",
#       "roleSource": "AUTO",
#       "collectionInterval": "NA",
#       "platformId": "AIR-AP1141N-A-K9",
#       "collectionStatus": "Managed",
#       "role": "ACCESS",
#       "lineCardId": null,
#       "type": "Cisco 1140 Unified Access Point",
#       "location": null,
#       "waasDeviceMode": null,
#       "apManagerInterfaceIp": "10.10.20.51",
#       "errorDescription": null,
#       "lastUpdated": "2019-03-05 02:05:53",
#       "managementIpAddress": "10.10.20.244",
#       "serialNumber": "1140K0004",
#       "inventoryStatusDetail": "NA",
#       "softwareVersion": "8.6.101.0",
#       "snmpLocation": "default-location",
#       "instanceTenantId": "SYS0",
#       "tagCount": "0"
#     },
#     {
#       "macAddress": "00:2b:01:00:06:00",
#       "upTime": "43days 01:17:07.610",
#       "bootDateTime": null,
#       "lastUpdateTime": 1551751553587,
#       "snmpContact": "",
#       "lineCardCount": null,
#       "series": "Cisco 1140 Series Unified Access Points",
#       "errorCode": "null",
#       "softwareType": null,
#       "interfaceCount": null,
#       "tunnelUdpPort": "16666",
#       "id": "0aafed14-666b-4f9d-a172-6f169798631a",
#       "locationName": null,
#       "associatedWlcIp": "10.10.20.51",
#       "instanceUuid": "0aafed14-666b-4f9d-a172-6f169798631a",
#       "family": "Unified AP",
#       "reachabilityFailureReason": "NA",
#       "reachabilityStatus": "Reachable",
#       "hostname": "T1-5",
#       "memorySize": "NA",
#       "roleSource": "AUTO",
#       "collectionInterval": "NA",
#       "platformId": "AIR-AP1141N-A-K9",
#       "collectionStatus": "Managed",
#       "role": "ACCESS",
#       "lineCardId": null,
#       "type": "Cisco 1140 Unified Access Point",
#       "location": null,
#       "waasDeviceMode": null,
#       "apManagerInterfaceIp": "10.10.20.51",
#       "errorDescription": null,
#       "lastUpdated": "2019-03-05 02:05:53",
#       "managementIpAddress": "10.10.20.245",
#       "serialNumber": "1140K0005",
#       "inventoryStatusDetail": "NA",
#       "softwareVersion": "8.6.101.0",
#       "snmpLocation": "default-location",
#       "instanceTenantId": "SYS0",
#       "tagCount": "0"
#     },
#     {
#       "macAddress": "00:2b:01:00:07:00",
#       "upTime": "43days 01:17:06.610",
#       "bootDateTime": null,
#       "lastUpdateTime": 1551751553587,
#       "snmpContact": "",
#       "lineCardCount": null,
#       "series": "Cisco 1140 Series Unified Access Points",
#       "errorCode": "null",
#       "softwareType": null,
#       "interfaceCount": null,
#       "tunnelUdpPort": "16666",
#       "id": "e641ce97-dbba-4024-b64c-2f88620bcc23",
#       "locationName": null,
#       "associatedWlcIp": "10.10.20.51",
#       "instanceUuid": "e641ce97-dbba-4024-b64c-2f88620bcc23",
#       "family": "Unified AP",
#       "reachabilityFailureReason": "NA",
#       "reachabilityStatus": "Reachable",
#       "hostname": "T1-6",
#       "memorySize": "NA",
#       "roleSource": "AUTO",
#       "collectionInterval": "NA",
#       "platformId": "AIR-AP1141N-A-K9",
#       "collectionStatus": "Managed",
#       "role": "ACCESS",
#       "lineCardId": null,
#       "type": "Cisco 1140 Unified Access Point",
#       "location": null,
#       "waasDeviceMode": null,
#       "apManagerInterfaceIp": "10.10.20.51",
#       "errorDescription": null,
#       "lastUpdated": "2019-03-05 02:05:53",
#       "managementIpAddress": "10.10.20.246",
#       "serialNumber": "1140K0006",
#       "inventoryStatusDetail": "NA",
#       "softwareVersion": "8.6.101.0",
#       "snmpLocation": "default-location",
#       "instanceTenantId": "SYS0",
#       "tagCount": "0"
#     },
#     {
#       "macAddress": "00:2b:01:00:08:00",
#       "upTime": "40days 01:25:08.650",
#       "bootDateTime": null,
#       "lastUpdateTime": 1551751553587,
#       "snmpContact": "",
#       "lineCardCount": null,
#       "series": "Cisco 1140 Series Unified Access Points",
#       "errorCode": "null",
#       "softwareType": null,
#       "interfaceCount": null,
#       "tunnelUdpPort": "16666",
#       "id": "3aaffd4f-0638-4a54-b242-1533e87de9a7",
#       "locationName": null,
#       "associatedWlcIp": "10.10.20.51",
#       "instanceUuid": "3aaffd4f-0638-4a54-b242-1533e87de9a7",
#       "family": "Unified AP",
#       "reachabilityFailureReason": "NA",
#       "reachabilityStatus": "Unreachable",
#       "hostname": "T1-7",
#       "memorySize": "NA",
#       "roleSource": "AUTO",
#       "collectionInterval": "NA",
#       "platformId": "AIR-AP1141N-A-K9",
#       "collectionStatus": "Unassociated",
#       "role": "ACCESS",
#       "lineCardId": null,
#       "type": "Cisco 1140 Unified Access Point",
#       "location": null,
#       "waasDeviceMode": null,
#       "apManagerInterfaceIp": "10.10.20.51",
#       "errorDescription": null,
#       "lastUpdated": "2019-03-05 02:05:53",
#       "managementIpAddress": "10.10.20.247",
#       "serialNumber": "1140K0007",
#       "inventoryStatusDetail": "NA",
#       "softwareVersion": "8.6.101.0",
#       "snmpLocation": "default-location",
#       "instanceTenantId": "SYS0",
#       "tagCount": "0"
#     },
#     {
#       "macAddress": "00:2b:01:00:09:00",
#       "upTime": "1days 19:42:28.050",
#       "bootDateTime": null,
#       "lastUpdateTime": 1551751553587,
#       "snmpContact": "",
#       "lineCardCount": null,
#       "series": "Cisco 1140 Series Unified Access Points",
#       "errorCode": "null",
#       "softwareType": null,
#       "interfaceCount": null,
#       "tunnelUdpPort": "16666",
#       "id": "a4e0a3ab-de5f-4ee2-822d-a5437b3eaf49",
#       "locationName": null,
#       "associatedWlcIp": "10.10.20.51",
#       "instanceUuid": "a4e0a3ab-de5f-4ee2-822d-a5437b3eaf49",
#       "family": "Unified AP",
#       "reachabilityFailureReason": "NA",
#       "reachabilityStatus": "Unreachable",
#       "hostname": "T1-8",
#       "memorySize": "NA",
#       "roleSource": "AUTO",
#       "collectionInterval": "NA",
#       "platformId": "AIR-AP1141N-A-K9",
#       "collectionStatus": "Unassociated",
#       "role": "ACCESS",
#       "lineCardId": null,
#       "type": "Cisco 1140 Unified Access Point",
#       "location": null,
#       "waasDeviceMode": null,
#       "apManagerInterfaceIp": "10.10.20.51",
#       "errorDescription": null,
#       "lastUpdated": "2019-03-05 02:05:53",
#       "managementIpAddress": "10.10.20.248",
#       "serialNumber": "1140K0008",
#       "inventoryStatusDetail": "NA",
#       "softwareVersion": "8.6.101.0",
#       "snmpLocation": "default-location",
#       "instanceTenantId": "SYS0",
#       "tagCount": "0"
#     },
#     {
#       "macAddress": "00:2b:01:00:0a:00",
#       "upTime": "1days 19:42:28.060",
#       "bootDateTime": null,
#       "lastUpdateTime": 1551751553587,
#       "snmpContact": "",
#       "lineCardCount": null,
#       "series": "Cisco 1140 Series Unified Access Points",
#       "errorCode": "null",
#       "softwareType": null,
#       "interfaceCount": null,
#       "tunnelUdpPort": "16666",
#       "id": "10cdbf6d-3672-4b4d-ae75-5b661fa0a5bc",
#       "locationName": null,
#       "associatedWlcIp": "10.10.20.51",
#       "instanceUuid": "10cdbf6d-3672-4b4d-ae75-5b661fa0a5bc",
#       "family": "Unified AP",
#       "reachabilityFailureReason": "NA",
#       "reachabilityStatus": "Unreachable",
#       "hostname": "T1-9",
#       "memorySize": "NA",
#       "roleSource": "AUTO",
#       "collectionInterval": "NA",
#       "platformId": "AIR-AP1141N-A-K9",
#       "collectionStatus": "Unassociated",
#       "role": "ACCESS",
#       "lineCardId": null,
#       "type": "Cisco 1140 Unified Access Point",
#       "location": null,
#       "waasDeviceMode": null,
#       "apManagerInterfaceIp": "10.10.20.51",
#       "errorDescription": null,
#       "lastUpdated": "2019-03-05 02:05:53",
#       "managementIpAddress": "10.10.20.249",
#       "serialNumber": "1140K0009",
#       "inventoryStatusDetail": "NA",
#       "softwareVersion": "8.6.101.0",
#       "snmpLocation": "default-location",
#       "instanceTenantId": "SYS0",
#       "tagCount": "0"
#     }
#   ]
# }

# %%
data = ", ".join([ "{}:{}".format(dev['managementIpAddress'],dev['platformId'])
                  for dev in response['response']])

# %%
print (data)
# Out:
# 10.10.20.51:AIR-CT3504-K9, 10.10.20.81:C9300-48U, 10.10.20.82:C9300-48U, 10.10.20.80:WS-C3850-24P-L, 10.10.20.241:AIR-AP1141N-A-K9, 10.10.20.250:AIR-AP1141N-A-K9, 10.10.20.242:AIR-AP1141N-A-K9, 10.10.20.243:AIR-AP1141N-A-K9, 10.10.20.244:AIR-AP1141N-A-K9, 10.10.20.245:AIR-AP1141N-A-K9, 10.10.20.246:AIR-AP1141N-A-K9, 10.10.20.247:AIR-AP1141N-A-K9, 10.10.20.248:AIR-AP1141N-A-K9, 10.10.20.249:AIR-AP1141N-A-K9

# %% [markdown]
# ## Templates

# %%
templates = get_url("dna/intent/api/v1/template-programmer/template")
# Out:
# https://sandboxdnac2.cisco.com:8080/dna/intent/api/v1/template-programmer/template

# %%
template = [ t for t in templates if t['projectName'] == "switching" and t['name'] == "interface-des"][0]

# %%
print(json.dumps(template, indent=2))
# Out:
# {
#   "versionsInfo": [
#     {
#       "description": "",
#       "author": "admin",
#       "versionComment": "",
#       "version": "1",
#       "versionTime": 1547865199368,
#       "id": "bd8fd41f-e449-441f-9ac1-804686a87c55"
#     }
#   ],
#   "name": "interface-des",
#   "composite": false,
#   "projectId": "dda1d3b7-788e-4608-8994-ab9ab676b03b",
#   "templateId": "8a91e0f1-de37-409b-8242-b344825833df",
#   "projectName": "switching"
# }

# %%
templateId= template['templateId']

# %%
print(templateId)
# Out:
# 8a91e0f1-de37-409b-8242-b344825833df

# %%
latest_id = 0
max = 0
for v in template['versionsInfo']:
    if int(v['version']) > max:
        max = int(v['version'])
        latest_id = v['id']
print(latest_id)
# Out:
# bd8fd41f-e449-441f-9ac1-804686a87c55

# %%
templateData = get_url("dna/intent/api/v1/template-programmer/template/{}".format(templateId))
# Out:
# https://sandboxdnac2.cisco.com:8080/dna/intent/api/v1/template-programmer/template/8a91e0f1-de37-409b-8242-b344825833df

# %%
print(json.dumps(templateData, indent=2))
# Out:
# {
#   "rollbackTemplateContent": "",
#   "deviceTypes": [
#     {
#       "productFamily": "Switches and Hubs"
#     }
#   ],
#   "softwareType": "IOS-XE",
#   "description": "",
#   "lastUpdateTime": 1547865193455,
#   "tags": [],
#   "composite": false,
#   "projectId": "dda1d3b7-788e-4608-8994-ab9ab676b03b",
#   "rollbackTemplateParams": [],
#   "parentTemplateId": "8a91e0f1-de37-409b-8242-b344825833df",
#   "softwareVariant": "XE",
#   "id": "8a91e0f1-de37-409b-8242-b344825833df",
#   "containingTemplates": [],
#   "templateParams": [
#     {
#       "instructionText": null,
#       "required": true,
#       "displayName": null,
#       "description": null,
#       "dataType": null,
#       "defaultValue": null,
#       "provider": null,
#       "binding": "",
#       "range": [],
#       "order": 1,
#       "notParam": false,
#       "selection": null,
#       "paramArray": false,
#       "key": null,
#       "parameterName": "interface",
#       "group": null,
#       "id": "de633ffd-2072-4fcf-a65b-0edc355a4a50"
#     },
#     {
#       "instructionText": null,
#       "required": true,
#       "displayName": null,
#       "description": null,
#       "dataType": null,
#       "defaultValue": null,
#       "provider": null,
#       "binding": "",
#       "range": [],
#       "order": 2,
#       "notParam": false,
#       "selection": null,
#       "paramArray": false,
#       "key": null,
#       "parameterName": "description",
#       "group": null,
#       "id": "e150c3c3-8936-489b-bb5f-3136a5a09fed"
#     }
#   ],
#   "projectName": "switching",
#   "createTime": 1547865173653,
#   "templateContent": "interface $interface\n  description $description",
#   "name": "interface-des"
# }

# %% [markdown]
# ### Applying the Template

# %%
payload = {
    "templateId": latest_id,
    "forcePushTemplate" : True,
    "targetInfo": [
     {

        "id": "10.10.20.81",
        "type": "MANAGED_DEVICE_IP",
        "params": {"description": "my Desc", "interface":"g1/0/12"}
        }
     ]
    }

# %%
deployment = deploy_and_wait("dna/intent/api/v1/template-programmer/template/deploy", payload)
# Out:
# https://sandboxdnac2.cisco.com:8080/dna/intent/api/v1/template-programmer/template/deploy
# Response {u'duration': u'0 seconds', u'deploymentId': u'Deployment of  Template: bd8fd41f-e449-441f-9ac1-804686a87c55.ApplicableTargets: [10.10.20.81]Template Deployemnt Id: 2ae67048-9435-485e-88c0-65bb54f570f0', u'endTime': u'', u'startTime': u''}
# waiting for deploymentId 2ae67048-9435-485e-88c0-65bb54f570f0
# https://sandboxdnac2.cisco.com:8080/api/v1/template-programmer/template/deploy/status/2ae67048-9435-485e-88c0-65bb54f570f0
# {u'status': u'SUCCESS', u'templateName': u'interface-des', u'projectName': u'switching', u'devices': [{u'status': u'SUCCESS', u'name': u'', u'detailedStatusMessage': u'Provisioning success for template interface-des', u'deviceId': u'6a49c827-9b28-490b-8df0-8b6c3b582d8a', u'startTime': u'02:45:51 05/03/2019', u'duration': u'0 minutes 1 seconds', u'endTime': u'', u'ipAddress': u'6a49c827-9b28-490b-8df0-8b6c3b582d8a'}], u'deploymentId': u'2ae67048-9435-485e-88c0-65bb54f570f0', u'startTime': u'', u'duration': u'0 seconds', u'endTime': u'02:45:51 05/03/2019', u'templateVersion': u'1'}

# %%
print(json.dumps(deployment,indent=2))
# Out:
# {
#   "status": "SUCCESS",
#   "templateName": "interface-des",
#   "projectName": "switching",
#   "devices": [
#     {
#       "status": "SUCCESS",
#       "name": "",
#       "detailedStatusMessage": "Provisioning success for template interface-des",
#       "deviceId": "6a49c827-9b28-490b-8df0-8b6c3b582d8a",
#       "startTime": "02:45:10 05/03/2019",
#       "duration": "0 minutes 1 seconds",
#       "endTime": "",
#       "ipAddress": "6a49c827-9b28-490b-8df0-8b6c3b582d8a"
#     }
#   ],
#   "deploymentId": "da940ef8-9c0a-490f-9781-80dd6c499f03",
#   "startTime": "",
#   "duration": "0 seconds",
#   "endTime": "02:45:11 05/03/2019",
#   "templateVersion": "1"
# }
